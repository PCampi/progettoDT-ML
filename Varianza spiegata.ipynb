# %% [markdown]
# # Analisi della varianza spiegata

# %%
# basic packages
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as pl

# scikit-learn ML utilities
from sklearn.cross_validation import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression

from decision_plots import *

# %matplotlib inline
# Out:
# /Users/pietro/Documents/Universita/Progetto_DT_ML/.venv/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
dataset = pd.read_excel("./Dataset/finali/integrato.xlsx", sheet_name='ML_finale') # already normalized dataset
print("Shape of the dataset: {}".format(dataset.shape))
# Out:
# Shape of the dataset: (164, 7)

# %%
dataset.head()
# Out:
#   Country code          Country name  Population  CO2 production (kg)  \
# 0          ABW                 Aruba      103795         8.727460e+08
# 1          AFG           Afghanistan    32758020         9.809225e+09
# 2          AGO                Angola    26920466         3.476316e+10
# 3          AND               Andorra       79223         4.620420e+08
# 4          ARE  United Arab Emirates     9070867         2.113695e+11
#
#    Charcoal consumption (kg)  Fuel oil consumption (kg)  \
# 0               4.670000e+05               9.000000e+06
# 1               1.259260e+08               4.407000e+08
# 2               1.164000e+09               3.081000e+09
# 3               2.900000e+04               1.299600e+08
# 4               6.400000e+07               4.957000e+09
#
#    Renewable energy consumption (percentage)
# 0                                   6.922234
# 1                                  16.748996
# 2                                  50.797466
# ...

# %% [markdown]
# ## Importanza delle feature con Random Forest

# %%
fig, ax = pl.subplots(ncols=1, figsize=(16,14))
g = sns.heatmap(dataset.corr(), annot=False, cmap="RdYlGn")
